# %% [markdown]
# <a href="https://colab.research.google.com/github/dntai/sgu25_fuzzy_logic_its_applications/blob/main/buoi02/ex2_scientific1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ex2_scientific1

# %% [markdown]
# ## Nội dung bài

# %% [markdown]
# Hiển thị ngẫu nhiên $N=50$ hình tròn:
# + Tâm $c_i = (x_i,y_i)$ ngẫu nhiên với $x_i, y_i \in \left[0, 1 \right]$
# + Màu sắc $color_i$ ngẫu nhiên với $color_i \in \left[0, 1 \right]$
# + Diện tích $area_i = \pi * r_i^2$ với sinh ngẫu nhiên $r_i \in \left[0, 1 \right]$

# %% [markdown]
# ## Bài làm

# %% [markdown]
# ### Import thư viện

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython import display # hiển thị rich output

# %% [markdown]
# ### Sinh ngẫu nhiên hình tròn

# %%
# %time
# generate randomly the center (x,y ) of circle, color, area
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi * (15 * np.random.rand(N)) ** 2  # 0 to 15 point radii
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.25 µs

# %%
# Mã kiểm tra dữ liệu
print(f'+ x: len={len(x):d}, [{min(x):.2f}, {max(x):.2f}]: 10 samples [{x[0:10]}]')
print(f'+ y: len={len(y):d}, [{min(y):.2f}, {max(y):.2f}]: 10 samples [{y[0:10]}]')
print(f'+ colors: len={len(colors):d}, [{min(colors):.2f}, {max(colors):.2f}]: 10 samples [{colors[0:10]}]')
print(f'+ area: len={len(area):d}, [{min(area):.2f}, {max(area):.2f}]: 10 samples [{area[0:10]}]')
# Out:
# + x: len=50, [0.02, 1.00]: 10 samples [[0.15181853 0.44299038 0.16105636 0.69554429 0.64530942 0.25843978
#  0.19764254 0.56608276 0.15288688 0.1292019 ]]
# + y: len=50, [0.01, 1.00]: 10 samples [[0.32009847 0.74179907 0.28140348 0.13356043 0.94709495 0.79589595
#  0.86294039 0.37734173 0.47908981 0.99931407]]
# + colors: len=50, [0.02, 1.00]: 10 samples [[0.37476804 0.69332779 0.38992381 0.67680537 0.02131726 0.25066023
#  0.3503026  0.45554938 0.85387682 0.59320958]]
# + area: len=50, [0.00, 688.75]: 10 samples [[3.49015263e-04 7.48780458e+01 1.48284219e+02 5.25428859e+02
#  5.99708883e+02 4.98234428e+02 4.98105167e+02 3.12931939e+02
#  5.16446728e+02 2.29250503e+02]]

# %% [markdown]
# ### Hiển thị đồ thị

# %%
# %matplotlib inline
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %% [markdown]
# # Kết thúc
